# %%
import
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-6-99021728f681> in <module>
# ----> 1 import git
#
# ModuleNotFoundError: No module named 'git'

# %%
#from UtilitiesLib import*
from matplotlib import pyplot as plt
import numpy as np
#import DataModule as dm
import E5063 as vna
import bokeh
import IPLIST
import CURSOURCE
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-4-315c2d85fdb7> in <module>
#       3 import numpy as np
#       4 #import DataModule as dm
# ----> 5 import E5063 as vna
#       6 import bokeh
#       7 import IPLIST
#
# ModuleNotFoundError: No module named 'E5063'

# %%
self=0

# %%
a=vna.VNA.collect_scan(self,f_range_mat=[0,10])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-9-62dc192db24d> in <module>
# ----> 1 a=vna.VNA.collect_scan(self,f_range_mat=[0,10])
#
# ~\Desktop\python repo\E5063.py in collect_scan(self, f_range_mat, npoints_v, navg_v, power_v, wait_v, BW_v)
#     575         y = []
#     576         range_mat = np.array(f_range_mat)
# --> 577         len_loop = len(range_mat[:,0])
#     578
#     579         def vector_handling(vector):
#
# IndexError: too many indices for array

# %%
a=dm.loa

# %%
a=dm.load_csv('measurements_vna/goldhund_line1_300to40K/s12.csv',skiprows=[i for i in range(6)])
b=dm.load_csv('measurements_vna/goldhund_line2_300to40K/s12.csv',skiprows=[i for i in range(7)])
c=dm.load_csv('measurements_vna/goldhund_line1_40to4K/s12.csv',skiprows=[i for i in range(7)])
d=dm.load_csv('measurements_vna/goldhund_line2_40to4K/s12.csv',skiprows=[i for i in range(7)])
a.x=a.x/1e9
b.x=b.x/1e9
c.x=c.x/1e9
d.x=d.x/1e9
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-15eb92aacea9> in <module>
# ----> 1 a=dm.load_csv('measurements_vna/goldhund_line1_300to40K/s12.csv',skiprows=[i for i in range(6)])
#       2 b=dm.load_csv('measurements_vna/goldhund_line2_300to40K/s12.csv',skiprows=[i for i in range(7)])
#       3 c=dm.load_csv('measurements_vna/goldhund_line1_40to4K/s12.csv',skiprows=[i for i in range(7)])
#       4 d=dm.load_csv('measurements_vna/goldhund_line2_40to4K/s12.csv',skiprows=[i for i in range(7)])
#       5 a.x=a.x/1e9
#
# NameError: name 'dm' is not defined

# %%
plt.plot(a.x,a.y)
plt.plot(b.x,b.y)
plt.plot(c.x,c.y)
plt.plot(d.x,d.y)
plt.legend(['line 1 - 300 to 40 k','line 2- 300 k to 40 k','line 1- 40 k to 4 k', 'line 2- 40k to 4k'])
plt.xlabel('Frequency (GHz)')
plt.ylabel('$|S_{21}|$ (dB)')
# Out:
# Text(0, 0.5, '$|S_{21}|$ (dB)')

# %%
e=dm.load_csv('measurements_vna/goldhund_line1_300to40K/s11.csv',skiprows=[i for i in range(6)])
f=dm.load_csv('measurements_vna/goldhund_line2_300to40K/s11.csv',skiprows=[i for i in range(7)])
g=dm.load_csv('measurements_vna/goldhund_line1_40to4K/s11.csv',skiprows=[i for i in range(7)])
h=dm.load_csv('measurements_vna/goldhund_line2_40to4K/s11.csv',skiprows=[i for i in range(7)])
e.x=e.x/1e9
f.x=f.x/1e9
g.x=g.x/1e9
h.x=h.x/1e9

# %%
plt.plot(e.x,e.y)
plt.plot(f.x,f.y)
plt.plot(g.x,g.y)
plt.plot(h.x,h.y)
plt.legend(['line 1 - 300 to 40 k','line 2- 300 k to 40 k','line 1- 40 k to 4 k', 'line 2- 40k to 4k'])
plt.xlabel('Frequency (GHz)')
plt.ylabel('$|S_{11}|$ (dB)')
# Out:
# Text(0, 0.5, '$|S_{11}|$ (dB)')

# %%
i=dm.load_csv('measurements_vna/goldhund_line1_300to40K/s22.csv',skiprows=[i for i in range(6)])
j=dm.load_csv('measurements_vna/goldhund_line2_300to40K/s22.csv',skiprows=[i for i in range(7)])
k=dm.load_csv('measurements_vna/goldhund_line1_40to4K/s22.csv',skiprows=[i for i in range(7)])
l=dm.load_csv('measurements_vna/goldhund_line2_40to4K/s22.csv',skiprows=[i for i in range(7)])
i.x=i.x/1e9
j.x=j.x/1e9
k.x=k.x/1e9
l.x=l.x/1e9

# %%
plt.plot(i.x,i.y)
plt.plot(j.x,j.y)
plt.plot(k.x,k.y)
plt.plot(l.x,l.y)
plt.legend(['line 1 - 300 to 40 k','line 2- 300 k to 40 k','line 1- 40 k to 4 k', 'line 2- 40k to 4k'])
plt.xlabel('Frequency (GHz)')
plt.ylabel('$|S_{22}|$ (dB)')
# Out:
# Text(0, 0.5, '$|S_{22}|$ (dB)')

# %%
thro1 = dm.load_csv('measurements_vna/goldhund_line1/s12.csv',skiprows=[i for i in range(6)])
thro2 = dm.load_csv('measurements_vna/goldhund_line2/s12.csv',skiprows=[i for i in range(6)])
p=dm.load_csv('measurements_vna/elspec_20765/s12.csv',skiprows=[i for i in range(6)])
p.x=p.x/1e9
thro1.x=thro1.x/1e9
thro2.x=thro2.x/1e9

# %%
plt.plot(thro1.x,thro1.y)
plt.plot(thro2.x,thro2.y)
plt.plot(p.x,p.y,'')
plt.legend(['line 1 ','line 2','unbent cable'])
plt.xlabel('Frequency (GHz)')
plt.ylabel('$|S_{12}|$ (dB)')
# Out:
# Text(0, 0.5, '$|S_{12}|$ (dB)')

# %%
p=dm.load_csv('measurements_vna/20201209_lna_RT.csv',skiprows=[i for i in range(1)])
r=dm.load_csv('measurements_vna/LNA_300mk.csv',skiprows=[i for i in range(6)])
p.x=p.x/1e9
r.x=r.x/1e9
# Out:
# C:\Users\PhaniRajaMuppalla\Desktop\python repo\DataModule\data_table.py:111: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.df[self.name_x][self.idx_min:self.idx_max] = value

# %%
plt.plot(p.x,p.y,'r')
plt.plot(r.x,r.y,'k')
plt.legend(['HEMT RT ','HEMT 300 mk'])
plt.xlabel('Frequency (GHz)')
plt.ylabel('$|S_{21}|$ (dB)')
# Out:
# Text(0, 0.5, '$|S_{21}|$ (dB)')

# %%
r=dm.load_csv('measurements_vna/SLR-55DBM POWER@600MK_2.CSV',skiprows=[i for i in range(7)])
r.x=(r.x)/1e+09

# %%
r.plot()
# Out:
# ...
#   <div class="bk-root" id="a05af7ce-e58a-4565-b2a5-9b43feafa0ae" data-root-id="6491"></div>
# Figure(id='6491', ...)

# %%
r.x
# Out:
# array([0.99691017, 0.99691405, 0.99691793, ..., 1.00309322, 1.0030971 ,
#        1.00310098])

# %%
r.fit(dm.mode_fit,[-37,6e3,1e-3,8.05,2e4],plot_init=False)
# Out:
# ...
#   <div class="bk-root" id="8361d420-7655-49ed-8a60-513118f41ecc" data-root-id="6857"></div>
#           Value         Error
# 0    -37.882975  2.523273e-03
# 1   6901.333222  1.859697e+01
# 2      0.000604  1.518218e-06
# 3      8.051242  8.429484e-07
# 4  23766.665216  1.175649e+02
# (array([-3.78829749e+01,  6.90133322e+03,  6.03994848e-04,  8.05124195e+00,
#          2.37666652e+04]),
#  array([2.52327313e-03, 1.85969746e+01, 1.51821817e-06, 8.42948449e-07,
#         1.17564905e+02]),
#  0.009018680352142422)

# %%
r.plot(engine='p')
plt.grid()
plt.xlabel('Frequency (GHz)')
plt.ylabel('S21 (dB)')
# Out:
# Text(0, 0.5, 'S21 (dB)')

# %%
plt.plot(a.x,a.y,'-o')
plt.xlabel('Frequency (GHz)')
plt.ylabel('$|S_{21}|$ (dB)' )
# Out:
# Text(0, 0.5, '$|S_{21}|$ (dB)')

# %%
a.x
# Out:
# array(['10000000', '22493750', '34987500', ..., '19987506250',
#        '20000000000', 'END'], dtype=object)

# %%
a.plot(engine='p')

# %%
import qucat
import qutip
from qucat import Network,GUI,L,J,C,R

# %%
cir_prog = Network([
C(0,1,100e-15), # transmon
J(0,1,'Lj'),
C(0,2,100e-15), # resonator
L(0,2,10e-9),
C(1,2,1e-15), # coupling capacitor
C(2,3,0.5e-15), # ext. coupl. cap.
R(3,0,50)]) # 50 Ohm load

# %%
cir = GUI('circuits/basics.txt', # location of the circuit file
        edit=True, # open the GUI to edit the circuit
        plot=True, # plot the circuit after having edited it
        print_network=True # print the network
       )
# Out:
# C 0 1 C1=1 fF
# J 0 1 Lj1
# C 0 2 1 fF
# C 1 2 100 fF
# J 1 2 Lj2=8 nH

# %%
H = cir.hamiltonian(
    modes = [0,1],# Include modes 0 and 1
    taylor = 4,# Taylor the Josephson potential to the power 4
    excitations = [8,10],# Consider 8 excitations in mode 0, 10 for mode 1
    Lj1 = 8e-9)# set any component values that were not fixed when building the circuit

# QuTiP method which return the eigenergies of the system
ee = H.eigenenergies()

# %%
first_transition = ee[1]-ee[0] # in units of Hertz
# print this frequency in GHz units
print("%.3f GHz"%((first_transition)/1e9))
# Out:
# 0.729 GHz

# %%
second_transition= ee[2]-ee[1]

print("%.3f GHz"%((second_transition))/1e9)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-9a926549fd6c> in <module>
#       1 second_transition= ee[2]-ee[1]
#       2
# ----> 3 print("%.3f GHz"%((second_transition))/1e9)
#
# TypeError: unsupported operand type(s) for /: 'str' and 'float'
